# %% [markdown]
# # Loading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# path settings and loading data @sabinvankathmandu
path = "../data/BostonHousing.csv"
df = pd.read_csv(path)

# %% [markdown]
# # Data structure and summary

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# statistical summarizations done @sabinvankathmandu
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# data set rows and columns @sabinvankathmandu
print(f"Dataset contains {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# Dataset contains 506 rows and 14 columns.

# %%
# columns name listing @sabinvankathmandu
df.columns.tolist()
# Out:
# ['crim',
#  'zn',
#  'indus',
#  'chas',
#  'nox',
#  'rm',
#  'age',
#  'dis',
#  'rad',
#  'tax',
#  'ptratio',
#  'b',
#  'lstat',
#  'medv']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# # Check for missing values

# %%
# Check for missing values @sabinvankathmandu
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# # Handling Missing values

# %%
# Dropping rows with missing values @sabinvankathmandu
df = df.dropna()
# check if rows with missing values are deleted
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# # Visualize relationships between features and the target variable.

# %%
# Set plot style @sabinvankathmandu
sns.set_theme(style="whitegrid")

# %%
# Histogram of features @sabinvankathmandu
df.hist(figsize=(12, 10), bins=20, edgecolor='black')
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# %%
# Boxplots for Each Column for outliers detections @sabinvankathmandu

# Setting the figure size @sabinvankathmandu
plt.figure(figsize=(15, 10))

# create a boxplot by looping for each columns @sabinvankathmandu
for i, column in enumerate(df.columns, 1):
    plt.subplot(4, 4, i)  # adjusting rows & cols as needed (4x4 for 16 features)
    sns.boxplot(y=df[column])
    plt.title(f"Boxplot of {column}")

plt.tight_layout()  # layout adujst to prevent overlapping @sabinvankathmandu
plt.show()

# %%
# Heat mAp or Correlation matrix @sabinvankathmandu

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# ### Distribution of Target Variables (MEDV)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["medv"], bins=30, kde=True)
plt.title("Distribution of MEDV (House Prices)")
plt.xlabel("MEDV (in $1000s)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Relationship Between MEDV (House Price) & Key Features

# %%
# top correlated features with MEDV @sabinvankathmandu
correlated_features = df.corr()["medv"].abs().sort_values(ascending=False)
print("Top Correlated Features with MEDV:\n", correlated_features)

# scatter plots for key factors
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
sns.scatterplot(x=df["rm"], y=df["medv"], ax=axes[0, 0]).set_title("Rooms vs Price")
sns.scatterplot(x=df["lstat"], y=df["medv"], ax=axes[0, 1]).set_title("LSTAT vs Price")
sns.scatterplot(x=df["ptratio"], y=df["medv"], ax=axes[1, 0]).set_title("PTRATIO vs Price")
sns.scatterplot(x=df["crim"], y=df["medv"], ax=axes[1, 1]).set_title("Crime Rate vs Price")

plt.tight_layout()
plt.show()
# Out:
# Top Correlated Features with MEDV:
#  medv       1.000000
# lstat      0.737720
# rm         0.696169
# ptratio    0.511897
# indus      0.486625
# tax        0.471253
# nox        0.428812
# crim       0.390251
# rad        0.384730
# age        0.375437
# zn         0.360031
# b          0.335387
# dis        0.251709
# chas       0.174679
# Name: medv, dtype: float64
